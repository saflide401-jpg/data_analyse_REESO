# %% [markdown]
# # TP-14 : Gestion des stocks – CAMEG (Solution Python)

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# %% [markdown]
# # Partie A : Données de stock
# # 1. DataFrame Produits

# %%
produits = pd.DataFrame({
    "Code_produit": ["P001","P002","P003","P004","P005"],
    "Designation": ["Paracetamol","Amoxicilline","Quinine","SRO","Ceftriaxone"],
    "Forme": ["Comprime","Capsule","Injectable","Sachet","Injectable"],
    "DCI": ["Paracetamol","Amoxicilline","Quinine","Sels de rehydratation","Ceftriaxone"],
    "Dosage": ["500mg","500mg","300mg","20.5g","1g"],
    "Unite": ["Boite","Boite","Ampoule","Sachet","Flacon"],
    "Prix_unitaire_FCFA": [500,1200,800,300,2500],
    "Fournisseur_principal": ["Lab A","Lab B","Lab C","Lab D","Lab B"],
    "Delai_reapprovisionnement_jours": [30,45,40,20,50]
})
print (produits)
# Out:
#   Code_produit   Designation       Forme                    DCI Dosage  \
# 0         P001   Paracetamol    Comprime            Paracetamol  500mg
# 1         P002  Amoxicilline     Capsule           Amoxicilline  500mg
# 2         P003       Quinine  Injectable                Quinine  300mg
# 3         P004           SRO      Sachet  Sels de rehydratation  20.5g
# 4         P005   Ceftriaxone  Injectable            Ceftriaxone     1g
#
#      Unite  Prix_unitaire_FCFA Fournisseur_principal  \
# 0    Boite                 500                 Lab A
# 1    Boite                1200                 Lab B
# 2  Ampoule                 800                 Lab C
# 3   Sachet                 300                 Lab D
# 4   Flacon                2500                 Lab B
#
#    Delai_reapprovisionnement_jours
# 0                               30
# 1                               45
# 2                               40
# 3                               20
# 4                               50

# %% [markdown]
# # 2. DataFrame Mouvements_stock

# %%
dates = pd.date_range(end=datetime.today(), periods=180)
print(dates)
# Out:
# DatetimeIndex(['2025-09-14 07:21:39.539444', '2025-09-15 07:21:39.539444',
#                '2025-09-16 07:21:39.539444', '2025-09-17 07:21:39.539444',
#                '2025-09-18 07:21:39.539444', '2025-09-19 07:21:39.539444',
#                '2025-09-20 07:21:39.539444', '2025-09-21 07:21:39.539444',
#                '2025-09-22 07:21:39.539444', '2025-09-23 07:21:39.539444',
#                ...
#                '2026-03-03 07:21:39.539444', '2026-03-04 07:21:39.539444',
#                '2026-03-05 07:21:39.539444', '2026-03-06 07:21:39.539444',
#                '2026-03-07 07:21:39.539444', '2026-03-08 07:21:39.539444',
#                '2026-03-09 07:21:39.539444', '2026-03-10 07:21:39.539444',
#                '2026-03-11 07:21:39.539444', '2026-03-12 07:21:39.539444'],
#               dtype='datetime64[us]', length=180, freq='D')

# %%
mouvements = []

depots = ["Central","Ouaga","Bobo","Ouahigouya"]
motifs = ["Achat","Vente","Peremption","Casse"]
vendeur=["Francis","alizata", "Aminata","Delfine", "Diane", "Siaka", "Latif"]


for d in dates:
    for code in produits["Code_produit"]:
        mouvements.append([
            d,
            code,
            np.random.choice(["Entree","Sortie"]),
            np.random.randint(10,200),
            np.random.choice(motifs),
            np.random.choice(depots),
            np.random.choice(vendeur)
        ])

mouvements_stock = pd.DataFrame(
    mouvements,
    columns=["Date","Code_produit","Type","Quantite","Motif","Depot", "vendeur"]
)

print("les mouvements du stock")
print(mouvements_stock.head())
# Out:
# les mouvements du stock
#                         Date Code_produit    Type  Quantite       Motif  \
# 0 2025-09-14 07:21:39.539444         P001  Sortie       108  Peremption
# 1 2025-09-14 07:21:39.539444         P002  Entree       101       Casse
# 2 2025-09-14 07:21:39.539444         P003  Sortie        29       Vente
# 3 2025-09-14 07:21:39.539444         P004  Sortie       152       Casse
# 4 2025-09-14 07:21:39.539444         P005  Sortie       132  Peremption
#
#         Depot  vendeur
# 0  Ouahigouya  Francis
# 1       Ouaga  Delfine
# 2       Ouaga  Francis
# 3        Bobo    Diane
# 4     Central  Francis

# %%
print("les informations sur le dataaframe mouvements_stocks\n".upper())
mouvements_stock.info()
print("\n la forme est:")
mouvements_stock.shape()
# Out:
# LES INFORMATIONS SUR LE DATAAFRAME MOUVEMENTS_STOCKS
#
# <class 'pandas.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          900 non-null    datetime64[us]
#  1   Code_produit  900 non-null    str
#  2   Type          900 non-null    str
#  3   Quantite      900 non-null    int64
#  4   Motif         900 non-null    str
#  5   Depot         900 non-null    str
#  6   vendeur       900 non-null    str
# dtypes: datetime64[us](1), int64(1), str(5)
# memory usage: 49.3 KB
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 4
#       1 print("les informations sur le dataaframe mouvements_stocks\n".upper())
#       2 mouvements_stock.info(),
# ----> 4 mouvements_stock.shape()
#
# TypeError: 'tuple' object is not callable

# %% [markdown]
# # Partie B : Calcul des stocks
# # 4. Stock actuel par produit et dépôt

# %%
mouvements_stock["Quantite_calc"] = np.where(
    mouvements_stock["Type"]=="Entree",
    mouvements_stock["Quantite"],
    -mouvements_stock["Quantite"]
)

stock_actuel = mouvements_stock.groupby(
    ["Code_produit","Depot"]
)["Quantite_calc"].sum().reset_index()

stock_actuel.rename(columns={"Quantite_calc":"Stock_actuel"}, inplace=True)
print(stock_actuel)
# Out:
#    Code_produit       Depot  Stock_actuel
# 0          P001        Bobo           199
# 1          P001     Central           832
# 2          P001       Ouaga          -524
# 3          P001  Ouahigouya           -15
# 4          P002        Bobo            44
# 5          P002     Central           -38
# 6          P002       Ouaga           273
# 7          P002  Ouahigouya          1010
# 8          P003        Bobo          -572
# 9          P003     Central           592
# 10         P003       Ouaga           589
# 11         P003  Ouahigouya           764
# 12         P004        Bobo         -1119
# 13         P004     Central          -313
# 14         P004       Ouaga           609
# 15         P004  Ouahigouya           597
# 16         P005        Bobo          -543
# 17         P005     Central           870
# 18         P005       Ouaga           -10
# 19         P005  Ouahigouya           152

# %%
# On multiplie la quantité par 1 si Entrée, sinon par -1
mouvements_stock["Stock_actuel"] = mouvements_stock["Quantite"] * mouvements_stock["Type"].map({"Entree": 1, "Sortie": -1})

stock_actuel = mouvements_stock.groupby(["Code_produit", "Depot"])["Stock_actuel"].sum().reset_index()
print("\n le stock actuel")
print(stock_actuel)
# Out:
#    Code_produit       Depot  Stock_actuel
# 0          P001        Bobo           199
# 1          P001     Central           832
# 2          P001       Ouaga          -524
# 3          P001  Ouahigouya           -15
# 4          P002        Bobo            44
# 5          P002     Central           -38
# 6          P002       Ouaga           273
# 7          P002  Ouahigouya          1010
# 8          P003        Bobo          -572
# 9          P003     Central           592
# 10         P003       Ouaga           589
# 11         P003  Ouahigouya           764
# 12         P004        Bobo         -1119
# 13         P004     Central          -313
# 14         P004       Ouaga           609
# 15         P004  Ouahigouya           597
# 16         P005        Bobo          -543
# 17         P005     Central           870
# 18         P005       Ouaga           -10
# 19         P005  Ouahigouya           152

# %%
# On pivote pour avoir une colonne Entree et une colonne Sortie
pivot = mouvements_stock.pivot_table(
    index=["Code_produit", "Depot"], 
    columns="Type", 
    values="Quantite", 
    aggfunc="sum", 
    fill_value=0
)

# Stock = Entrées - Sorties
pivot["Stock_actuel"] = pivot["Entree"] - pivot.get("Sortie", 0)
stock_actuel = pivot["Stock_actuel"].reset_index()
print(stock_actuel)
# Out:
#    Code_produit       Depot  Stock_actuel
# 0          P001        Bobo           199
# 1          P001     Central           832
# 2          P001       Ouaga          -524
# 3          P001  Ouahigouya           -15
# 4          P002        Bobo            44
# 5          P002     Central           -38
# 6          P002       Ouaga           273
# 7          P002  Ouahigouya          1010
# 8          P003        Bobo          -572
# 9          P003     Central           592
# 10         P003       Ouaga           589
# 11         P003  Ouahigouya           764
# 12         P004        Bobo         -1119
# 13         P004     Central          -313
# 14         P004       Ouaga           609
# 15         P004  Ouahigouya           597
# 16         P005        Bobo          -543
# 17         P005     Central           870
# 18         P005       Ouaga           -10
# 19         P005  Ouahigouya           152

# %% [markdown]
# # 5. Consommation Moyenne Mensuelle (CMM)

# %%
sorties = mouvements_stock[mouvements_stock["Type"]=="Sortie"]

cmm = sorties.groupby("Code_produit")["Quantite"].sum() / 6
cmm = cmm.reset_index()
cmm.rename(columns={"Quantite":"CMM"}, inplace=True)

print("\n les mouvements de sorties".upper())
print(sorties)

print ("\n la commande moyennemensuelle:")
print(cmm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sorties = mouvements_stock[mouvements_stock["Type"]=="Sortie"]
#       3 cmm = sorties.groupby("Code_produit")["Quantite"].sum() / 6
#       4 cmm = cmm.reset_index()
#
# NameError: name 'mouvements_stock' is not defined

# %% [markdown]
# # 6. Stock de sécurité

# %%
cmm["Stock_securite"] = 2 * cmm["CMM"]
print(cmm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cmm["Stock_securite"] = 2 * cmm["CMM"]
#       2 print(cmm)
#
# NameError: name 'cmm' is not defined

# %% [markdown]
# # 7. Niveau de commande

# %%
produits_cmm = produits.merge(cmm, on="Code_produit")

produits_cmm["consommation_moyenne_journaliere"] = produits_cmm["CMM"] / 30

produits_cmm["Niveau_commande"] = (
    produits_cmm["Stock_securite"] +
    produits_cmm["Delai_reapprovisionnement_jours"] *
    produits_cmm["consommation_moyenne_journaliere"]
)
print(produits_cmm)
# Out:
#   Code_produit   Designation       Forme                    DCI Dosage  \
# 0         P001   Paracetamol    Comprime            Paracetamol  500mg
# 1         P002  Amoxicilline     Capsule           Amoxicilline  500mg
# 2         P003       Quinine  Injectable                Quinine  300mg
# 3         P004           SRO      Sachet  Sels de rehydratation  20.5g
# 4         P005   Ceftriaxone  Injectable            Ceftriaxone     1g
#
#      Unite  Prix_unitaire_FCFA Fournisseur_principal  \
# 0    Boite                 500                 Lab A
# 1    Boite                1200                 Lab B
# 2  Ampoule                 800                 Lab C
# 3   Sachet                 300                 Lab D
# 4   Flacon                2500                 Lab B
#
#    Delai_reapprovisionnement_jours          CMM  Stock_securite  \
# 0                               30  1515.666667     3031.333333
# 1                               45  1520.166667     3040.333333
# 2                               40  1468.166667     2936.333333
# 3                               20  1628.833333     3257.666667
# 4                               50  1514.333333     3028.666667
#
#    consommation_moyenne_journaliere  Niveau_commande
# 0                         50.522222      4547.000000
# 1                         50.672222      5320.583333
# 2                         48.938889      4893.888889
# 3                         54.294444      4343.555556
# 4                         50.477778      5552.555556

# %% [markdown]
# # Partie C : Alertes de stock
# # 8. Classification des stocks

# %%
stock = stock_actuel.merge(produits_cmm, on="Code_produit")

def statut_stock(row):
    
    if row["Stock_actuel"] == 0:
        return "Rupture"
    
    elif row["Stock_actuel"] < row["Stock_securite"]:
        return "Alerte critique"

    elif row["Stock_actuel"] < row["Niveau_commande"]:
        return "Alerte"
    
    elif row["Stock_actuel"] > 12 * row["CMM"]:
        return "Surstock"
    
    else:
        return "Stock correct"
    print("stçck classifier")

stock["Statut"] = stock.apply(statut_stock, axis=1)

# %% [markdown]
# # 9. Rapport d’alerte

# %%
priorite = {
    "Rupture":1,
    "Alerte critique":2,
    "Alerte":3,
    "Stock correct":4,
    "Surstock":5
}

stock["Priorite"] = stock["Statut"].map(priorite)

rapport_alerte = stock.sort_values("Priorite")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 9
#       1 priorite = {
#       2     "Rupture":1,
#       3     "Alerte critique":2,
#    (...)      6     "Surstock":5
#       7 }
# ----> 9 stock["Priorite"] = stock["Statut"].map(priorite)
#      11 rapport_alerte = stock.sort_values("Priorite")
#
# NameError: name 'stock' is not defined

# %% [markdown]
# # 10. Valeur financière des stocks

# %%
stock["Valeur_stock"] = stock["Stock_actuel"] * stock["Prix_unitaire_FCFA"]
print("valeur des stocks")
valeur_depot = stock.groupby("Depot")["Valeur_stock"].sum()

# %% [markdown]
# # Partie D : Analyse des mouvements
# # 11. Sorties par mois et produit

# %%
sorties["Mois"] = sorties["Date"].dt.to_period("M")

analyse_mensuelle = sorties.groupby(
    ["Mois","Code_produit"]
)["Quantite"].sum().reset_index()

# %% [markdown]
# # 12. Produits avec fortes variations

# %%
variation = analyse_mensuelle.groupby("Code_produit")["Quantite"].std()

variation = variation.sort_values(ascending=False)

# %% [markdown]
# # 13. Coût des pertes

# %%
pertes = mouvements_stock[
    mouvements_stock["Motif"].isin(["Peremption","Casse"])
]

pertes = pertes.merge(produits[["Code_produit","Prix_unitaire_FCFA"]], on="Code_produit")

pertes["Cout"] = pertes["Quantite"] * pertes["Prix_unitaire_FCFA"]

cout_total_pertes = pertes["Cout"].sum()

# %% [markdown]
# # Partie E : Prévisions
# # 14. Besoins pour les 3 prochains mois

# %%
previsions = cmm.copy()

previsions["Besoin_3_mois"] = 3 * previsions["CMM"]

# %% [markdown]
# # 15. Génération des commandes

# %%
commandes = stock.merge(previsions, on="Code_produit")

commandes["Quantite_commande"] = (
    commandes["Besoin_3_mois"] + commandes["Stock_securite"]
    - commandes["Stock_actuel"]
)

commandes["Quantite_commande"] = commandes["Quantite_commande"].apply(
    lambda x: max(0, x)
)

commandes_finales = commandes[commandes["Quantite_commande"] > 0][
    ["Code_produit","Depot","Quantite_commande"]
]
