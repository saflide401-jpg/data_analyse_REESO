# %%
# Travaux Pratiques - Séance 17

# TP 17.1 : Analyse de séries temporelles de ventes
#### Objectif : Manipuler et analyser des données temporelles.

# %% [markdown]
# # 1. Création de données quotidiennes
# np.random.seed(42)

# %%
import pandas as pd
# Format wide (large)
ventes_wide = pd.DataFrame({
'Region': ['Centre', 'Nord', 'Hauts-Bassins'],
'T1': [1000, 800, 1200],
'T2': [1100, 850, 1250],
'T3': [1050, 900, 1300],
'T4': [1200, 950, 1400]
})

# %%
print("Format WIDE :")
print(ventes_wide)
# Out:
# Format WIDE :
#           Region    T1    T2    T3    T4
# 0         Centre  1000  1100  1050  1200
# 1           Nord   800   850   900   950
# 2  Hauts-Bassins  1200  1250  1300  1400
